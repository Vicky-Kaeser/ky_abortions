# %% [markdown]
# # ky_abortions
#
#
# As a daughter, a mother, a sister, a wife, a granddaughter, and a woman I want to share this data with you and with as many people as possible. Please share this valuable information wherever possible.

# %% [markdown]
# ## Who is having abortions in Kentucky?
#
# This data shows a different picture from what antiabortion individuals would like you to believe.
# Ten years of data from 2009 to 2019 (2017 data was not available) is documented within seven data sets in this project (with the exception of the ethnicity table).
# An additional data set shows reproductive health and rights under attack by the law makers in Kentucky.

# %% [markdown]
# ### Data Source:
# [Centers for Disease Control and Prevention-Abortion Surveillance](https://search.cdc.gov/search/?query=kentucky%27s%20abortion%20clinics&dpage=1#results-web)
#
# [Guttmacher Institute](https://www.guttmacher.org/laws-affecting-reproductive-health-and-rights-2011-state-policy-review)

# %%
#verify python version
# !python --version
# Out:
# Python 3.10.4

# %%
#import packages - see requirements.txt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
age_df = pd.read_excel ('data_raw/age_gps/age_gps.xlsx')
age_df.head(20)
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2     Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN        NaN            NaN        NaN
# 1         NaN  KENTUCKY         NaN  ABORTION DATA        NaN
# 2         NaN        NaN        NaN            NaN        NaN
# 3         NaN        NaN        NaN            NaN        NaN
# 4        YEAR  AGE GROUP        NaN            NaN        NaN
# 5         NaN        <15      15-19          20-24      25-29
# 6        2009         28        691           1296        973
# 7        2010         23        589           1273        905
# 8        2011         22        567           1295        929
# 9        2012         25        483           1241        963
# 10       2013         16        465           1229        846
# 11       2014         17        408           1098        874
# 12       2015         16        337           1037        851
# 13       2016         15        343            995        935
# ...

# %%
age_df.columns=['YEAR','<15','15-19','20-24','25-29','30-34','35-39','>=40','8','TOTAL']

# %%
age_df
# Out:
#     YEAR        <15  15-19          20-24  25-29                       30-34  \
# 0    NaN        NaN    NaN            NaN    NaN                         NaN
# 1    NaN  KENTUCKY     NaN  ABORTION DATA    NaN  YEARS 2009-2016, 2018-2019
# 2    NaN        NaN    NaN            NaN    NaN                         NaN
# 3    NaN        NaN    NaN            NaN    NaN                         NaN
# 4   YEAR  AGE GROUP    NaN            NaN    NaN                         NaN
# 5    NaN        <15  15-19          20-24  25-29                       30-34
# 6   2009         28    691           1296    973                         612
# 7   2010         23    589           1273    905                         624
# 8   2011         22    567           1295    929                         607
# 9   2012         25    483           1241    963                         613
# 10  2013         16    465           1229    846                         642
# ...

# %%
 age_df1=age_df.dropna(how='all', axis='columns')

# %%
age_df2 = age_df1.iloc[6:,0:].copy()

# %%
age_df2
# Out:
#     YEAR <15 15-19 20-24 25-29 30-34 35-39 >=40 TOTAL
# 6   2009  28   691  1296   973   612   377  143  4120
# 7   2010  23   589  1273   905   624   373  142  3929
# 8   2011  22   567  1295   929   607   384  153  3957
# 9   2012  25   483  1241   963   613   369  116  3810
# 10  2013  16   465  1229   846   642   326  113  3637
# 11  2014  17   408  1098   874   575   349  121  3442
# 12  2015  16   337  1037   851   521   288  138  3188
# 13  2016  15   343   995   935   556   358  110  3312
# 14  2018  14   287   933   917   601   338  113  3203
# 15  2019  11   294  1071  1069   719   384  116  3664

# %%
age_df2.set_index('YEAR', inplace=True)
# Out:
# c:\Users\Vicky\anaconda3\envs\abortion\lib\site-packages\pandas\core\indexes\base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)

# %%
age_df2
# Out:
#      <15 15-19 20-24 25-29 30-34 35-39 >=40 TOTAL
# YEAR
# 2009  28   691  1296   973   612   377  143  4120
# 2010  23   589  1273   905   624   373  142  3929
# 2011  22   567  1295   929   607   384  153  3957
# 2012  25   483  1241   963   613   369  116  3810
# 2013  16   465  1229   846   642   326  113  3637
# 2014  17   408  1098   874   575   349  121  3442
# 2015  16   337  1037   851   521   288  138  3188
# 2016  15   343   995   935   556   358  110  3312
# 2018  14   287   933   917   601   338  113  3203
# 2019  11   294  1071  1069   719   384  116  3664

# %%
plt.plot(age_df2['TOTAL'])
plt.title('Kentucky Ten Year Abortion Data \n From 2009 to 2019 (2017 No Data Available)')
# Out:
# Text(0.5, 1.0, 'Kentucky Ten Year Abortion Data \n From 2009 to 2019 (2017 No Data Available)')

# %%
gestation_df = pd.read_excel ('data_raw/gestation/gestation.xlsx')
gestation_df.head(20)
# Out:
#    Unnamed: 0           Unnamed: 1 Unnamed: 2     Unnamed: 3 Unnamed: 4  \
# 0         NaN                  NaN        NaN            NaN        NaN
# 1         NaN            KENTUCKY         NaN  ABORTION DATA        NaN
# 2         NaN                  NaN        NaN            NaN        NaN
# 3        YEAR  WEEKS OF GESTATION         NaN            NaN        NaN
# 4         NaN                  <=8       9-13          14-15      16-17
# 5        2009                 2589       1098            175         99
# 6        2010                 2428       1044            170        107
# 7        2011                 2450       1089            141        108
# 8        2012                 2354       1074            138         85
# 9        2013                 2233       1011            148         87
# 10       2014                 2123        934            147        101
# 11       2015                 2004        804            122        105
# ...

# %%
gestation_df.columns=['YEAR','WKS<=8', 'WKS9-13', 'WKS14-15', 'WKS16-17', 'WKS18-20', 'WKS>=21', '7', 'NaN1', 'TOTAL']

# %%
gestation_df
# Out:
#     YEAR               WKS<=8 WKS9-13       WKS14-15 WKS16-17  \
# 0    NaN                  NaN     NaN            NaN      NaN
# 1    NaN            KENTUCKY      NaN  ABORTION DATA      NaN
# 2    NaN                  NaN     NaN            NaN      NaN
# 3   YEAR  WEEKS OF GESTATION      NaN            NaN      NaN
# 4    NaN                  <=8    9-13          14-15    16-17
# 5   2009                 2589    1098            175       99
# 6   2010                 2428    1044            170      107
# 7   2011                 2450    1089            141      108
# 8   2012                 2354    1074            138       85
# 9   2013                 2233    1011            148       87
# 10  2014                 2123     934            147      101
# 11  2015                 2004     804            122      105
# 12  2016                 2020     863            152      127
# 13  2018                 2010     887            126       64
# ...

# %%
 gestation_df1=gestation_df.dropna(how='all', axis='columns')

# %%
gestation_df2 = gestation_df1.iloc[5:,0:].copy()

# %%
gestation_df2
# Out:
#     YEAR WKS<=8 WKS9-13 WKS14-15 WKS16-17 WKS18-20 WKS>=21 TOTAL
# 5   2009   2589    1098      175       99      111      48  4120
# 6   2010   2428    1044      170      107      130      50  3929
# 7   2011   2450    1089      141      108      113      56  3957
# 8   2012   2354    1074      138       85      117      42  3810
# 9   2013   2233    1011      148       87      112      46  3637
# 10  2014   2123     934      147      101       88      49  3442
# 11  2015   2004     804      122      105      107      46  3188
# 12  2016   2020     863      152      127      117      33  3312
# 13  2018   2010     887      126       64       85      31  3203
# 14  2019   2495     850      116       65      109      29  3664

# %%
gestation_df2.set_index('YEAR', inplace=True)
# Out:
# c:\Users\Vicky\anaconda3\envs\abortion\lib\site-packages\pandas\core\indexes\base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)

# %%
gestation_df2
# Out:
#      WKS<=8 WKS9-13 WKS14-15 WKS16-17 WKS18-20 WKS>=21 TOTAL
# YEAR
# 2009   2589    1098      175       99      111      48  4120
# 2010   2428    1044      170      107      130      50  3929
# 2011   2450    1089      141      108      113      56  3957
# 2012   2354    1074      138       85      117      42  3810
# 2013   2233    1011      148       87      112      46  3637
# 2014   2123     934      147      101       88      49  3442
# 2015   2004     804      122      105      107      46  3188
# 2016   2020     863      152      127      117      33  3312
# 2018   2010     887      126       64       85      31  3203
# 2019   2495     850      116       65      109      29  3664

# %%
gestation_WKS =sns.relplot(data=gestation_df2, kind='line', x='YEAR', y="WKS<=8")

# %%
ethnicity_df = pd.read_excel('data_raw/ethnicity/ethnicity.xlsx')
ethnicity_df.head(20)
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2     Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN        NaN            NaN        NaN
# 1         NaN  KENTUCKY         NaN  ABORTION DATA        NaN
# 2         NaN        NaN        NaN            NaN        NaN
# 3         NaN        NaN        NaN            NaN        NaN
# 4        YEAR      WHITE     BLACK        HISPANIC      OTHER
# 5        2009       2783        981            101        255
# 6        2011       2618        993            178        168
# 7        2012       2504        984            135        187
# 8        2015       2009        863            171        145
# 9        2016       2056        892            195        169
# 10       2018       1873        973            228        129
# 11       2019       2041       1236            253        134
#
#                                      Unnamed: 5  Unnamed: 6
# 0                                           NaN         NaN
# ...

# %%
ethnicity_df.columns=['YEAR','WHITE','BLACK','HISPANIC','OTHER','5','TOTAL']

# %%
ethnicity_df
# Out:
#     YEAR      WHITE   BLACK       HISPANIC  OTHER  \
# 0    NaN        NaN     NaN            NaN    NaN
# 1    NaN  KENTUCKY      NaN  ABORTION DATA    NaN
# 2    NaN        NaN     NaN            NaN    NaN
# 3    NaN        NaN     NaN            NaN    NaN
# 4   YEAR      WHITE  BLACK        HISPANIC  OTHER
# 5   2009       2783     981            101    255
# 6   2011       2618     993            178    168
# 7   2012       2504     984            135    187
# 8   2015       2009     863            171    145
# 9   2016       2056     892            195    169
# 10  2018       1873     973            228    129
# 11  2019       2041    1236            253    134
#
#                                               5   TOTAL
# 0                                           NaN     NaN
# 1   YEARS 2009, 2011-2012, 2015-2016, 2018-2019     NaN
# 2                                           NaN     NaN
# 3                                           NaN     NaN
# ...

# %%
ethnicity_df1=ethnicity_df.dropna(how='all', axis='columns')

# %%
ethnicity_df1.drop(['5'], axis=1, inplace=True)

# %%
ethnicity_df2 = ethnicity_df1.iloc[5:,0:].copy()

# %%
ethnicity_df2
# Out:
#     YEAR WHITE BLACK HISPANIC OTHER   TOTAL
# 5   2009  2783   981      101   255  4120.0
# 6   2011  2618   993      178   168  3957.0
# 7   2012  2504   984      135   187  3810.0
# 8   2015  2009   863      171   145  3188.0
# 9   2016  2056   892      195   169  3312.0
# 10  2018  1873   973      228   129  3203.0
# 11  2019  2041  1236      253   134  3664.0

# %%
ethnicity_df2.set_index('YEAR', inplace=True)
# Out:
# c:\Users\Vicky\anaconda3\envs\abortion\lib\site-packages\pandas\core\indexes\base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)

# %%
ethnicity_df2
# Out:
#      WHITE BLACK HISPANIC OTHER   TOTAL
# YEAR
# 2009  2783   981      101   255  4120.0
# 2011  2618   993      178   168  3957.0
# 2012  2504   984      135   187  3810.0
# 2015  2009   863      171   145  3188.0
# 2016  2056   892      195   169  3312.0
# 2018  1873   973      228   129  3203.0
# 2019  2041  1236      253   134  3664.0

# %%
marital_df=pd.read_excel('data_raw/marital_status/marital_status.xlsx')
marital_df.head(20)
# Out:
#    Unnamed: 0      Unnamed: 1 Unnamed: 2     Unnamed: 3  Unnamed: 4  \
# 0         NaN             NaN        NaN            NaN         NaN
# 1         NaN       KENTUCKY         NaN  ABORTION DATA         NaN
# 2         NaN             NaN        NaN            NaN         NaN
# 3         NaN             NaN        NaN            NaN         NaN
# 4        YEAR  MARITAL STATUS        NaN            NaN         NaN
# 5         NaN         MARRIED  UNMARRIED            NaN         NaN
# 6        2009             519       3601            NaN      4120.0
# 7        2010             583       3346            NaN      3929.0
# 8        2011             559       3398            NaN      3957.0
# 9        2012             537       3273            NaN      3810.0
# 10       2013             486       3151            NaN      3637.0
# 11       2014             474       2968            NaN      3442.0
# 12       2015             511       2677            NaN      3188.0
# ...

# %%
marital_df.columns=['YEAR','MARRIED','UNMARRIED','3','TOTAL','5']

# %%
marital_df
# Out:
#     YEAR         MARRIED  UNMARRIED              3   TOTAL  \
# 0    NaN             NaN        NaN            NaN     NaN
# 1    NaN       KENTUCKY         NaN  ABORTION DATA     NaN
# 2    NaN             NaN        NaN            NaN     NaN
# 3    NaN             NaN        NaN            NaN     NaN
# 4   YEAR  MARITAL STATUS        NaN            NaN     NaN
# 5    NaN         MARRIED  UNMARRIED            NaN     NaN
# 6   2009             519       3601            NaN  4120.0
# 7   2010             583       3346            NaN  3929.0
# 8   2011             559       3398            NaN  3957.0
# 9   2012             537       3273            NaN  3810.0
# 10  2013             486       3151            NaN  3637.0
# 11  2014             474       2968            NaN  3442.0
# 12  2015             511       2677            NaN  3188.0
# 13  2016             494       2818            NaN  3312.0
# 14  2018             479       2724            NaN  3203.0
# ...

# %%
marital_df1=marital_df.dropna(how='all', axis='columns')

# %%
marital_df1.drop(['3','5'], axis=1, inplace=True)

# %%
marital_df2 = marital_df1.iloc[6:,0:].copy()

# %%
marital_df2
# Out:
#     YEAR MARRIED UNMARRIED   TOTAL
# 6   2009     519      3601  4120.0
# 7   2010     583      3346  3929.0
# 8   2011     559      3398  3957.0
# 9   2012     537      3273  3810.0
# 10  2013     486      3151  3637.0
# 11  2014     474      2968  3442.0
# 12  2015     511      2677  3188.0
# 13  2016     494      2818  3312.0
# 14  2018     479      2724  3203.0
# 15  2019     525      3139  3664.0

# %%
marital_df2.set_index('YEAR', inplace=True)
# Out:
# c:\Users\Vicky\anaconda3\envs\abortion\lib\site-packages\pandas\core\indexes\base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)

# %%
marital_df2
# Out:
#      MARRIED UNMARRIED   TOTAL
# YEAR
# 2009     519      3601  4120.0
# 2010     583      3346  3929.0
# 2011     559      3398  3957.0
# 2012     537      3273  3810.0
# 2013     486      3151  3637.0
# 2014     474      2968  3442.0
# 2015     511      2677  3188.0
# 2016     494      2818  3312.0
# 2018     479      2724  3203.0
# 2019     525      3139  3664.0

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
#sns.relplot(x='YEAR', y='TOTAL', col='MARRIED', data=marital_df2);

# %%
method_df=pd.read_excel('data_raw/method/method.xlsx')

# %%
method_df
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2     Unnamed: 3  Unnamed: 4  \
# 0         NaN        NaN        NaN            NaN         NaN
# 1         NaN  KENTUCKY         NaN  ABORTION DATA         NaN
# 2         NaN        NaN        NaN            NaN         NaN
# 3         NaN        NaN        NaN            NaN         NaN
# 4        YEAR     METHOD        NaN            NaN         NaN
# 5         NaN   SURGICAL    MEDICAL            NaN         NaN
# 6        2009       3520        593            NaN         NaN
# 7        2010       3140        785            NaN         NaN
# 8        2011       2955        998            NaN         NaN
# 9        2012       2768       1042            NaN         NaN
# 10       2013       2543       1094            NaN         NaN
# 11       2014       2336       1104            NaN         NaN
# 12       2015       1970       1218            NaN         NaN
# 13       2016       1819       1493            NaN         NaN
# ...

# %%
method_df.columns=['YEAR','SURGICAL','MEDICAL','3','4','TOTAL']

# %%
method_df
# Out:
#     YEAR   SURGICAL  MEDICAL              3   4                       TOTAL
# 0    NaN        NaN      NaN            NaN NaN                         NaN
# 1    NaN  KENTUCKY       NaN  ABORTION DATA NaN  YEARS 2009-2016, 2018-2019
# 2    NaN        NaN      NaN            NaN NaN                         NaN
# 3    NaN        NaN      NaN            NaN NaN                         NaN
# 4   YEAR     METHOD      NaN            NaN NaN                         NaN
# 5    NaN   SURGICAL  MEDICAL            NaN NaN                         NaN
# 6   2009       3520      593            NaN NaN                        4113
# 7   2010       3140      785            NaN NaN                        3925
# 8   2011       2955      998            NaN NaN                        3953
# 9   2012       2768     1042            NaN NaN                        3810
# 10  2013       2543     1094            NaN NaN                        3637
# ...

# %%
method_df1=method_df.dropna(how='all', axis='columns')

# %%
method_df1.drop(['3'], axis=1, inplace=True)
# Out:
# C:\Users\Vicky\AppData\Local\Temp\ipykernel_5004\2561460617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method_df1.drop(['3'], axis=1, inplace=True)

# %%
method_df2 = method_df1.iloc[6:,0:3].copy()

# %%
method_df2
# Out:
#     YEAR SURGICAL MEDICAL
# 6   2009     3520     593
# 7   2010     3140     785
# 8   2011     2955     998
# 9   2012     2768    1042
# 10  2013     2543    1094
# 11  2014     2336    1104
# 12  2015     1970    1218
# 13  2016     1819    1493
# 14  2018     1653    1550
# 15  2019     1818    1846

# %%
#method_df2.set_index('YEAR', inplace=True)

# %%
method_df2
# Out:
#     YEAR SURGICAL MEDICAL
# 6   2009     3520     593
# 7   2010     3140     785
# 8   2011     2955     998
# 9   2012     2768    1042
# 10  2013     2543    1094
# 11  2014     2336    1104
# 12  2015     1970    1218
# 13  2016     1819    1493
# 14  2018     1653    1550
# 15  2019     1818    1846

# %%
melted_method = pd.melt(method_df2, ['YEAR'])

# %%
melted_method
# Out:
#     YEAR  variable value
# 0   2009  SURGICAL  3520
# 1   2010  SURGICAL  3140
# 2   2011  SURGICAL  2955
# 3   2012  SURGICAL  2768
# 4   2013  SURGICAL  2543
# 5   2014  SURGICAL  2336
# 6   2015  SURGICAL  1970
# 7   2016  SURGICAL  1819
# 8   2018  SURGICAL  1653
# 9   2019  SURGICAL  1818
# 10  2009   MEDICAL   593
# 11  2010   MEDICAL   785
# 12  2011   MEDICAL   998
# 13  2012   MEDICAL  1042
# 14  2013   MEDICAL  1094
# 15  2014   MEDICAL  1104
# 16  2015   MEDICAL  1218
# 17  2016   MEDICAL  1493
# 18  2018   MEDICAL  1550
# 19  2019   MEDICAL  1846

# %%
sns.barplot(data=melted_method[melted_method.variable=="MEDICAL"], x="YEAR", y="value")
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %%
sns.barplot(data=melted_method[melted_method.variable=="SURGICAL"], x="YEAR", y="value")
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %%
prior_births_df=pd.read_excel('data_raw/previous_births/previous_births.xlsx')

# %%
prior_births_df
# Out:
#    Unnamed: 0                      Unnamed: 1  Unnamed: 2     Unnamed: 3  \
# 0         NaN                             NaN         NaN            NaN
# 1         NaN                       KENTUCKY          NaN  ABORTION DATA
# 2         NaN                             NaN         NaN            NaN
# 3         NaN                             NaN         NaN            NaN
# 4        YEAR  NUMBER OF PREVIOUS LIVE BIRTHS         NaN            NaN
# 5         NaN                               0         1.0              2
# 6        2009                            1648      1175.0            797
# 7        2010                            1540      1123.0            828
# 8        2011                            1586      1091.0            810
# 9        2012                            1533      1011.0            785
# 10       2013                            1474       985.0            740
# 11       2014                            1325       943.0            696
# ...

# %%
prior_births_df.columns=['YEAR','BIRTHS0','BIRTHS1','BIRTHS2','BIRTHS3','BIRTHS>=4','6','7','TOTAL']

# %%
prior_births_df
# Out:
#     YEAR                         BIRTHS0  BIRTHS1        BIRTHS2  BIRTHS3  \
# 0    NaN                             NaN      NaN            NaN      NaN
# 1    NaN                       KENTUCKY       NaN  ABORTION DATA      NaN
# 2    NaN                             NaN      NaN            NaN      NaN
# 3    NaN                             NaN      NaN            NaN      NaN
# 4   YEAR  NUMBER OF PREVIOUS LIVE BIRTHS      NaN            NaN      NaN
# 5    NaN                               0      1.0              2      3.0
# 6   2009                            1648   1175.0            797    331.0
# 7   2010                            1540   1123.0            828    280.0
# 8   2011                            1586   1091.0            810    316.0
# 9   2012                            1533   1011.0            785    315.0
# 10  2013                            1474    985.0            740    288.0
# 11  2014                            1325    943.0            696    298.0
# ...

# %%
prior_births_df1=prior_births_df.dropna(how='all', axis='columns')

# %%
prior_births_df1
# Out:
#     YEAR                         BIRTHS0  BIRTHS1        BIRTHS2  BIRTHS3  \
# 0    NaN                             NaN      NaN            NaN      NaN
# 1    NaN                       KENTUCKY       NaN  ABORTION DATA      NaN
# 2    NaN                             NaN      NaN            NaN      NaN
# 3    NaN                             NaN      NaN            NaN      NaN
# 4   YEAR  NUMBER OF PREVIOUS LIVE BIRTHS      NaN            NaN      NaN
# 5    NaN                               0      1.0              2      3.0
# 6   2009                            1648   1175.0            797    331.0
# 7   2010                            1540   1123.0            828    280.0
# 8   2011                            1586   1091.0            810    316.0
# 9   2012                            1533   1011.0            785    315.0
# 10  2013                            1474    985.0            740    288.0
# 11  2014                            1325    943.0            696    298.0
# ...

# %%
prior_births_df2 = prior_births_df1.iloc[6:,0:].copy()

# %%
prior_births_df2
# Out:
#     YEAR BIRTHS0  BIRTHS1 BIRTHS2  BIRTHS3 BIRTHS>=4   TOTAL
# 6   2009    1648   1175.0     797    331.0       169  4120.0
# 7   2010    1540   1123.0     828    280.0       158  3929.0
# 8   2011    1586   1091.0     810    316.0       107  3910.0
# 9   2012    1533   1011.0     785    315.0       166  3810.0
# 10  2013    1474    985.0     740    288.0       150  3637.0
# 11  2014    1325    943.0     696    298.0       180  3442.0
# 12  2015    1254    894.0     625    287.0       128  3188.0
# 13  2016    1246    877.0     728    292.0       169  3312.0
# 14  2018    1224    825.0     670    311.0       173  3203.0
# 15  2019    1300    934.0     871    338.0       221  3664.0

# %%
prior_births_df2.set_index('YEAR', inplace=True)
# Out:
# c:\Users\Vicky\anaconda3\envs\abortion\lib\site-packages\pandas\core\indexes\base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)

# %%
prior_births_df2
# Out:
#      BIRTHS0  BIRTHS1 BIRTHS2  BIRTHS3 BIRTHS>=4   TOTAL
# YEAR
# 2009    1648   1175.0     797    331.0       169  4120.0
# 2010    1540   1123.0     828    280.0       158  3929.0
# 2011    1586   1091.0     810    316.0       107  3910.0
# 2012    1533   1011.0     785    315.0       166  3810.0
# 2013    1474    985.0     740    288.0       150  3637.0
# 2014    1325    943.0     696    298.0       180  3442.0
# 2015    1254    894.0     625    287.0       128  3188.0
# 2016    1246    877.0     728    292.0       169  3312.0
# 2018    1224    825.0     670    311.0       173  3203.0
# 2019    1300    934.0     871    338.0       221  3664.0

# %%
prior_abortions_df=pd.read_excel('data_raw/previous_abortions/previous_abortions.xlsx')

# %%
prior_abortions_df
# Out:
#    Unnamed: 0                            Unnamed: 1  Unnamed: 2  \
# 0         NaN                                   NaN         NaN
# 1         NaN                             KENTUCKY          NaN
# 2         NaN                                   NaN         NaN
# 3        YEAR  NUMBER OF PREVIOUS INDUCED ABORTIONS         NaN
# 4         NaN                                     0         1.0
# 5        2009                                  2537      1013.0
# 6        2010                                  2430       923.0
# 7        2011                                  2496       929.0
# 8        2012                                  2330       888.0
# 9        2013                                  2284       847.0
# 10       2014                                  2153       801.0
# 11       2015                                  2032       733.0
# 12       2016                                  2148       740.0
# 13       2018                                  2074       706.0
# ...

# %%
prior_abortions_df.columns=['YEAR','ABORTIONS0','ABORTIONS1','ABORTIONS2','ABORTIONS>=3','5','TOTAL']

# %%
prior_abortions_df1=prior_abortions_df.dropna(how='all', axis='columns')

# %%
prior_abortions_df1
# Out:
#     YEAR                            ABORTIONS0  ABORTIONS1     ABORTIONS2  \
# 0    NaN                                   NaN         NaN            NaN
# 1    NaN                             KENTUCKY          NaN  ABORTION DATA
# 2    NaN                                   NaN         NaN            NaN
# 3   YEAR  NUMBER OF PREVIOUS INDUCED ABORTIONS         NaN            NaN
# 4    NaN                                     0         1.0              2
# 5   2009                                  2537      1013.0            358
# 6   2010                                  2430       923.0            323
# 7   2011                                  2496       929.0            330
# 8   2012                                  2330       888.0            349
# 9   2013                                  2284       847.0            287
# 10  2014                                  2153       801.0            294
# 11  2015                                  2032       733.0            258
# ...

# %%
prior_abortions_df1.drop(['5'], axis=1, inplace=True)

# %%
prior_abortion_df2=prior_abortions_df1.iloc[5:,0:].copy()

# %%
prior_abortion_df2
# Out:
#     YEAR ABORTIONS0  ABORTIONS1 ABORTIONS2 ABORTIONS>=3   TOTAL
# 5   2009       2537      1013.0        358          211  4119.0
# 6   2010       2430       923.0        323          253  3929.0
# 7   2011       2496       929.0        330          202  3957.0
# 8   2012       2330       888.0        349          243  3810.0
# 9   2013       2284       847.0        287          219  3637.0
# 10  2014       2153       801.0        294          194  3442.0
# 11  2015       2032       733.0        258           88  3111.0
# 12  2016       2148       740.0        249          175  3312.0
# 13  2018       2074       706.0        245          178  3203.0
# 14  2019       2324       866.0        293          181  3664.0

# %%
prior_abortion_df2.set_index('YEAR', inplace=True)
# Out:
# c:\Users\Vicky\anaconda3\envs\abortion\lib\site-packages\pandas\core\indexes\base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)

# %%
prior_abortion_df2
# Out:
#      ABORTIONS0  ABORTIONS1 ABORTIONS2 ABORTIONS>=3   TOTAL
# YEAR
# 2009       2537      1013.0        358          211  4119.0
# 2010       2430       923.0        323          253  3929.0
# 2011       2496       929.0        330          202  3957.0
# 2012       2330       888.0        349          243  3810.0
# 2013       2284       847.0        287          219  3637.0
# 2014       2153       801.0        294          194  3442.0
# 2015       2032       733.0        258           88  3111.0
# 2016       2148       740.0        249          175  3312.0
# 2018       2074       706.0        245          178  3203.0
# 2019       2324       866.0        293          181  3664.0

# %%
opposing_laws_df = pd.read_excel('data_raw/opposing_laws/opposing_laws.xlsx')

# %%
opposing_laws_df
# Out:
#     Unnamed: 0 Unnamed: 1                 Unnamed: 2  \
# 0          NaN       YEAR              OPPOSING LAWS
# 1          NaN       2010             House Bill 549
# 2          NaN       2010  Affordable Healthcare Act
# 3          NaN       2017               House Bill 2
# 4          NaN       2018             House Bill 100
# 5          NaN       2018             House Bill 454
# 6          NaN       2019             Senate Bill 50
# 7          NaN       2019              Senate Bill 9
# 8          NaN       2019               House Bill 5
# 9          NaN       2019             House Bill 148
# 10         NaN       2021    Attorney General powers
# 11         NaN       2022               House Bill 3
# 12         NaN       2022     Roe v. Wade overturned
# 13         NaN       2022    Nov. 2022 House Bill 91
#
#                                            Unnamed: 3
# 0                                         DESCRIPTION
# 1    To amend KY's Constitution- no right to abortion
# ...

# %%
opposing_laws_df.columns=['a','YEAR','OPPOSING LAWS', 'DESCRIPTION']

# %%
opposing_laws_df
# Out:
#      a  YEAR              OPPOSING LAWS  \
# 0  NaN  YEAR              OPPOSING LAWS
# 1  NaN  2010             House Bill 549
# 2  NaN  2010  Affordable Healthcare Act
# 3  NaN  2017               House Bill 2
# 4  NaN  2018             House Bill 100
# 5  NaN  2018             House Bill 454
# 6  NaN  2019             Senate Bill 50
# 7  NaN  2019              Senate Bill 9
# 8  NaN  2019               House Bill 5
# 9  NaN  2019             House Bill 148
# 10 NaN  2021    Attorney General powers
# 11 NaN  2022               House Bill 3
# 12 NaN  2022     Roe v. Wade overturned
# 13 NaN  2022    Nov. 2022 House Bill 91
#
#                                           DESCRIPTION
# 0                                         DESCRIPTION
# 1    To amend KY's Constitution- no right to abortion
# 2            AHA - no Federal funds for abortion care
# 3                                  Ultrasound mandate
# 4   Restrictions on providers and clinics-detectab...
# ...

# %%
opposing_laws_df1 = opposing_laws_df.dropna(how='all', axis='columns')

# %%
opposing_laws_df1
# Out:
#     YEAR              OPPOSING LAWS  \
# 0   YEAR              OPPOSING LAWS
# 1   2010             House Bill 549
# 2   2010  Affordable Healthcare Act
# 3   2017               House Bill 2
# 4   2018             House Bill 100
# 5   2018             House Bill 454
# 6   2019             Senate Bill 50
# 7   2019              Senate Bill 9
# 8   2019               House Bill 5
# 9   2019             House Bill 148
# 10  2021    Attorney General powers
# 11  2022               House Bill 3
# 12  2022     Roe v. Wade overturned
# 13  2022    Nov. 2022 House Bill 91
#
#                                           DESCRIPTION
# 0                                         DESCRIPTION
# 1    To amend KY's Constitution- no right to abortion
# 2            AHA - no Federal funds for abortion care
# 3                                  Ultrasound mandate
# 4   Restrictions on providers and clinics-detectab...
# 5                       Ban D&E -Dilation &Evacuation
# ...

# %%
opposing_laws_df2 = opposing_laws_df1.iloc[1:, 0:].copy()

# %%
opposing_laws_df2
# Out:
#     YEAR              OPPOSING LAWS  \
# 1   2010             House Bill 549
# 2   2010  Affordable Healthcare Act
# 3   2017               House Bill 2
# 4   2018             House Bill 100
# 5   2018             House Bill 454
# 6   2019             Senate Bill 50
# 7   2019              Senate Bill 9
# 8   2019               House Bill 5
# 9   2019             House Bill 148
# 10  2021    Attorney General powers
# 11  2022               House Bill 3
# 12  2022     Roe v. Wade overturned
# 13  2022    Nov. 2022 House Bill 91
#
#                                           DESCRIPTION
# 1    To amend KY's Constitution- no right to abortion
# 2            AHA - no Federal funds for abortion care
# 3                                  Ultrasound mandate
# 4   Restrictions on providers and clinics-detectab...
# 5                       Ban D&E -Dilation &Evacuation
# 6        Abortion Reversal Bill --abortion medication
# 7                            The Fetal Heartbeat Bill
# ...

# %%
merged = pd.merge(marital_df2, ethnicity_df2, on= 'YEAR')

# %%
merged
# Out:
#      MARRIED UNMARRIED  TOTAL_x WHITE BLACK HISPANIC OTHER  TOTAL_y
# YEAR
# 2009     519      3601   4120.0  2783   981      101   255   4120.0
# 2011     559      3398   3957.0  2618   993      178   168   3957.0
# 2012     537      3273   3810.0  2504   984      135   187   3810.0
# 2015     511      2677   3188.0  2009   863      171   145   3188.0
# 2016     494      2818   3312.0  2056   892      195   169   3312.0
# 2018     479      2724   3203.0  1873   973      228   129   3203.0
# 2019     525      3139   3664.0  2041  1236      253   134   3664.0

# %%
merged1 =merged.drop(['TOTAL_x', 'TOTAL_y'], axis=1)
merged1
# Out:
#      MARRIED UNMARRIED WHITE BLACK HISPANIC OTHER
# YEAR
# 2009     519      3601  2783   981      101   255
# 2011     559      3398  2618   993      178   168
# 2012     537      3273  2504   984      135   187
# 2015     511      2677  2009   863      171   145
# 2016     494      2818  2056   892      195   169
# 2018     479      2724  1873   973      228   129
# 2019     525      3139  2041  1236      253   134

# %%
##sns.relplot(data=piv6,
            #y='value', x='year',
            #kind='line', row='age_group',
            #height=1, aspect=10)##
